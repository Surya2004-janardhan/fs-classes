# %% [markdown]
# Functions in Python are blocks of reusable code that run only when called, and they can take inputs (parameters) and optionally give back outputs (return values). Learning them well makes programs cleaner, shorter, and easier to debug.

# %%
def dummy(num1, num2): # function parameters
    # temp = num1 * num2

    return num1*num2
#  function defination ends here + delcaratin 

# function call
var = dummy(5,6) # calling fun with arguments
# var1 = dummy(10)
# var1 = dummy(10)
# var1 = dummy(1034)
# var1 = dummy(10)
# var1 = dummy(10)
# var1 = dummy(10)
# var1 = dummy(10)
print(var)
# print(var1)
# Out:
# 30

# %%
arr = [1,2,3,4,5]
arr2 = [6,7,8,9,10]


# print(sum())
def sum_of_array(some_list):
    c_sum = 0
    for i in some_list:
        c_sum = c_sum + i
    return c_sum
result = sum_of_array(arr)
res = sum_of_array(arr2)
print(res)
print(result)


def say_hello():
    # return "Hello " + name
    print("hellow")

    
say_hello()
say_hello()
say_hello()
say_hello()



# c_sum1 = 0
# for i in arr2:
#     # print(i, c_sum)
#     c_sum1 = c_sum1 + i
# print(c_sum1)
# Out:
# 40
# 15
# hellow
# hellow
# hellow
# hellow

# %%
a = 43
a
# Out:
# 43

# %% [markdown]
# Linked list - Linear data structure where each element (node) points to the next (node),
# allowing for efficient insertion and deletion. It consists of nodes that contain
# data and a reference to the next node in the sequence.

# %%
# linked list class 

# | prev | data | next |

class Node:
    def __init__(self, value):
        self.prev = None
        self.data = value
        self.next = None

# obj for node


#  | 10 | None |


node1 = Node(10) # creating node with value 10 and next = none 
node2 = Node(10) 
node3 = Node(30)
node4 = Node(40)

# linked list u cant accesss in btw nodes - first node is called as head node 

# doubly linked list - each node has 3 parts - prev, data, next
# singly linked list - each node has 2 parts - data, next

node1 , node1.data, node1.next

# putting together doubly linked list
node1.next = node2
node2.prev = node1
node2.next = node3
node3.prev = node2
node3.next = node4
node4.prev = node3

# below code to make doubly linked list circular -
#  last node will point to first node and first node will point to last node
node4.next = node1
node1.prev = node4

# %%
print(node1.next.next.data)


# nums = [1,2,3,4,5]
# Out:
# 30

# %%
# traversing linked list - accessing each node one by one
head = node1
current = head


while current is not None:
    print(current.data)

    final_node = current 


    if current.data == 20 :
        node2 = current 
    if current.data == 30 :
        node3 = current
    # node1 = node1.next  = current becomes  node 2
    current = current.next


    #  4th.next 



# | none  | 10 | next | 
# # now current store last node lets do reverse traversal
tail  = node4

current = tail
while current is not None:
    print(current.data)
    current = current.prev
# Out:
# 40 10 10
# 10 10 30
# 10 30 40
# 30 40 10
# {<__main__.Node object at 0x000001E13D009D00>, <__main__.Node object at 0x000001E13D124BF0>, <__main__.Node object at 0x000001E13CE37170>, <__main__.Node object at 0x000001E13CE82570>}

# %%
# single list insertion deletion 

# singly linked list - each node has 2 parts - data, next

class Node():
    def __init__(self, value):
        self.data = value
        self.next = None

node1 = Node(10)
node2 = Node(20)
node3 = Node(30)
node4 = Node(40)

node1.next = node2
node2.next = node3
node3.next = node4
node4.next = None

print(node1.next , node1.next.data)

# 1 -> 2 -> 3 -> 4 -> None
# head
# Out:
# <__main__.Node object at 0x0000027A5739AE70> 20

# %%
# insertion at  head 

node0 = Node(0)
node0.next = node1

# 0 -> 1 -> 2 -> 3 -> 4 -> None

# insertion at tail
node5 = Node(50)
final_node.next = node5

# 0 -> 1 -> 2 -> 25-> 3 -> 4 -> 5 -> None

# insertion at middle - 25 in btw 20 and 30

node25 = Node(25)


node2.next = node25

node25.next = node3

# %%
# delete the head node 
# 1 -> 2 -> 25-> 3 -> 4 ->       5 -> None

head 
head = head.next

# delete the last node 

prevToTail.next = None

# delete the middle node - 25
first_node.next = third_node

# %%
# double every node value in linked list
head = node1 
current = head 
# node2.data = 0
# node4.data = 0
# # ey node ithey 80 value danni 0 
i = 0
while current is not None:
    print(current.data)
    current = current.next
# Out:
# 0
# 10
# 0
# 10

# %%
print(head.data, head.next.data, head.next.next.data, head.next.next.next.data)
# Out:
# 0 10 0 10
